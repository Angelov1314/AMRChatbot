# %%
import pandas as pd

# Load the data (you can also use pd.DataFrame() if you create them manually)
Demographics = pd.read_csv("Demongraphics.csv")
Conversations = pd.read_csv("amr_survey_ouput.csv")

# Perform inner join on phone_number
merged_df = pd.merge(Demographics Conversations, on="email address", how="inner")

# Show result
print(merged_df)
